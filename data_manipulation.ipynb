# %% [markdown]
# # 0 - VERİ SETİ HAZIRLANMASI

# %%
# Veri işlemesi ve analizi kütüphaneleri
import pandas as pd
import numpy as np
# Veri görselleştirme kütüphanleri
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Excel dosyasının yolu
dosya_yolu = r"C:\Users\Muhammed Emre\Desktop\Laptop-Price-Prediction\notebook.xlsx"

# Excel dosyasını oku ve DataFrame'e aktar
df_ = pd.read_excel(dosya_yolu)

# Kopyalama yaptık
df = df_.copy()

# %% [markdown]
# # 1 - VERİYE İLK BAKIŞ

# %%
# DataFrame'i görüntüle
df.head(n=4)
# default olarak verseydik 5 tane sonuç döndürür. -> df.head()
# eğer sondan kayıtları listelemek isteseydik -> df.tail()
# Out:
#   Arttırılabilir Azami Bellek             Bağlantılar Cihaz Ağırlığı  \
# 0                       16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 1                       16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 2                       16 GB  USB - Bluetooth - HDMI   2 kg ve altı
# 3                       32 GB  USB - Bluetooth - HDMI       2 - 4 kg
#
#   Dokunmatik Ekran Ekran Boyutu              Ekran Kartı  \
# 0              Yok     15,6 inç  Nvidia GeForce RTX 4060
# 1              Yok     15,6 inç  Nvidia GeForce RTX 3050
# 2              Yok     15,6 inç  Nvidia GeForce RTX 2050
# 3              Yok     15,6 inç  Nvidia GeForce RTX 4050
#
#   Ekran Kartı Bellek Tipi Ekran Kartı Gücü Ekran Kartı Hafızası  \
# 0                   GDDR6              NaN                 8 GB
# 1                   GDDR6              NaN                 6 GB
# 2                   GDDR6              55W         4 GB ve altı
# 3                   GDDR6             105W                 6 GB
#
#   Ekran Kartı Tipi  ... Temel İşlemci Hızı (GHz)  \
# 0           Harici  ...                      NaN
# 1           Harici  ...                      NaN
# 2           Harici  ...                      2.3
# 3           Harici  ...                      3.1
#
#                                                Title   Çözünürlük  \
# 0  LOQ 15IAX9 83GS007XTR i5-12450HX 8GB 512 GB SS...  1920 x 1080
# 1  G15-5530 Intel Core i7-13650HX 16GB 512GB SSD ...  1920 x 1080
# 2  Abra A5 V21.3 Intel Core i7 12700H 16 GB RAM 5...  1920 x 1080
# 3  LOQ Intel Core i5-12450HX 16GB 512GB SSD 6GB R...  1920 x 1080
#
#   Çözünürlük Standartı İşlemci Modeli İşlemci Nesli   İşlemci Tipi  \
# 0        Full HD (FHD)  Belirtilmemiş     12. Nesil  Intel Core i5
# 1        Full HD (FHD)        13650HX     13. Nesil  Intel Core i7
# 2        Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 3        Full HD (FHD)         12450H     12. Nesil  Intel Core i5
#
#    İşlemci Çekirdek Sayısı İşletim Sistemi Şarjlı Kullanım Süresi
# 0                      8.0        Free Dos                    NaN
# 1                     24.0        Free Dos                    NaN
# 2                     14.0        Free Dos               4-6 Saat
# 3                      8.0        Free Dos         6 Saat ve Üstü
#
# [4 rows x 35 columns]

# %%
df.shape # (satır x sütun)
# Out:
# (1200, 35)

# %%
print(df.ndim) # Verinin kaç boyutlu olduğunu gösterir.
# Out:
# 2

# %%
# Veri setindeki kolonları yazdırır.
print(list(df.columns), '\n')

# len() fonksiyonu ile toplam kolon sayısına erişiyoruz.
print(f"Veri seti içerisinde toplam {len(df.columns)} kolon vardır.\n")

# Çoğu zaman kullandığımız attribute ve fonksiyonların sonuçlarının hangi tipte veri döndürdüğünü gözlemlemek kod üzerinde hakimiyet kurmak için önemlidir.
print(f"df.columns'un döndüğü veri tipi: {type(df.columns)}\n")
# Out:
# ['Arttırılabilir Azami Bellek', 'Bağlantılar', 'Cihaz Ağırlığı', 'Dokunmatik Ekran', 'Ekran Boyutu', 'Ekran Kartı', 'Ekran Kartı Bellek Tipi', 'Ekran Kartı Gücü', 'Ekran Kartı Hafızası', 'Ekran Kartı Tipi', 'Ekran Yenileme Hızı', 'Garanti Süresi', 'Garanti Tipi', 'Hard Disk Kapasitesi', 'Kapasite', 'Klavye', 'Kullanım Amacı', 'Maksimum İşlemci Hızı (GHz)', 'Menşei', 'Panel Tipi', 'Price', 'Ram (Sistem Belleği)', 'Ram (Sistem Belleği) Tipi', 'Renk', 'SSD Kapasitesi', 'Temel İşlemci Hızı (GHz)', 'Title', 'Çözünürlük', 'Çözünürlük Standartı', 'İşlemci Modeli', 'İşlemci Nesli', 'İşlemci Tipi', 'İşlemci Çekirdek Sayısı', 'İşletim Sistemi', 'Şarjlı Kullanım Süresi']
#
# Veri seti içerisinde toplam 35 kolon vardır.
#
# df.columns'un döndüğü veri tipi: <class 'pandas.core.indexes.base.Index'>

# %%
# Veri hakkında bilgi verir.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Arttırılabilir Azami Bellek  810 non-null    object
#  1   Bağlantılar                  1197 non-null   object
#  2   Cihaz Ağırlığı               1200 non-null   object
#  3   Dokunmatik Ekran             1200 non-null   object
#  4   Ekran Boyutu                 1200 non-null   object
#  5   Ekran Kartı                  1200 non-null   object
#  6   Ekran Kartı Bellek Tipi      1200 non-null   object
#  7   Ekran Kartı Gücü             260 non-null    object
#  8   Ekran Kartı Hafızası         1200 non-null   object
#  9   Ekran Kartı Tipi             1200 non-null   object
#  10  Ekran Yenileme Hızı          1200 non-null   object
#  11  Garanti Süresi               1200 non-null   object
#  12  Garanti Tipi                 1200 non-null   object
#  13  Hard Disk Kapasitesi         1200 non-null   object
#  14  Kapasite                     1 non-null      object
#  15  Klavye                       1200 non-null   object
#  16  Kullanım Amacı               1200 non-null   object
#  17  Maksimum İşlemci Hızı (GHz)  742 non-null    float64
#  18  Menşei                       10 non-null     object
#  19  Panel Tipi                   1199 non-null   object
#  20  Price                        893 non-null    object
#  21  Ram (Sistem Belleği)         1200 non-null   object
#  22  Ram (Sistem Belleği) Tipi    1200 non-null   object
#  23  Renk                         1200 non-null   object
#  24  SSD Kapasitesi               1200 non-null   object
#  25  Temel İşlemci Hızı (GHz)     433 non-null    object
#  26  Title                        1200 non-null   object
#  27  Çözünürlük                   1200 non-null   object
#  28  Çözünürlük Standartı         1200 non-null   object
#  29  İşlemci Modeli               1200 non-null   object
#  30  İşlemci Nesli                1200 non-null   object
#  31  İşlemci Tipi                 1200 non-null   object
#  32  İşlemci Çekirdek Sayısı      1199 non-null   float64
#  33  İşletim Sistemi              1200 non-null   object
#  34  Şarjlı Kullanım Süresi       315 non-null    object
# dtypes: float64(2), object(33)
# memory usage: 328.3+ KB

# %%
# Sütunların hangi tipte olduğunu söyler.
df.dtypes
# Out:
# Arttırılabilir Azami Bellek     object
# Bağlantılar                     object
# Cihaz Ağırlığı                  object
# Dokunmatik Ekran                object
# Ekran Boyutu                    object
# Ekran Kartı                     object
# Ekran Kartı Bellek Tipi         object
# Ekran Kartı Gücü                object
# Ekran Kartı Hafızası            object
# Ekran Kartı Tipi                object
# Ekran Yenileme Hızı             object
# Garanti Süresi                  object
# Garanti Tipi                    object
# Hard Disk Kapasitesi            object
# Kapasite                        object
# Klavye                          object
# Kullanım Amacı                  object
# Maksimum İşlemci Hızı (GHz)    float64
# Menşei                          object
# Panel Tipi                      object
# Price                           object
# Ram (Sistem Belleği)            object
# Ram (Sistem Belleği) Tipi       object
# Renk                            object
# SSD Kapasitesi                  object
# Temel İşlemci Hızı (GHz)        object
# Title                           object
# Çözünürlük                      object
# Çözünürlük Standartı            object
# İşlemci Modeli                  object
# İşlemci Nesli                   object
# İşlemci Tipi                    object
# İşlemci Çekirdek Sayısı        float64
# İşletim Sistemi                 object
# Şarjlı Kullanım Süresi          object
# dtype: object

# %%
# SSD kapasitesini GB cinsine çevirecek bir fonksiyon
def convert_tb_to_gb(ssd_capacity):
    if 'TB' in ssd_capacity:
        # Eğer TB varsa, GB'ye çevir
        return str(int(ssd_capacity.split()[0]) * 1024) + " GB"  # 1 TB = 1024 GB
    else:
        # GB ise olduğu gibi bırak
        return ssd_capacity

# Sadece TB olanları dönüştürüp yeni bir sütun ekliyoruz
df["SSD Kapasitesi"] = df["SSD Kapasitesi"].apply(convert_tb_to_gb)

# %%
df["SSD Kapasitesi"].head(n=20)
# Out:
# 0      512 GB
# 1      512 GB
# 2      500 GB
# 3      512 GB
# 4      500 GB
# 5     1024 GB
# 6     1024 GB
# 7     1024 GB
# 8     2048 GB
# 9      512 GB
# 10     512 GB
# 11     512 GB
# 12     512 GB
# 13    1024 GB
# 14     512 GB
# 15     512 GB
# 16     512 GB
# 17    1024 GB
# 18     512 GB
# 19     512 GB
# Name: SSD Kapasitesi, dtype: object

# %%
import pandas as pd

# Sayısal sütunlar
sayisal_sutunlar = [
     'Ekran Kartı Gücü',"Ekran Yenileme Hızı", 'Hard Disk Kapasitesi', 'Maksimum İşlemci Hızı (GHz)', 
    'Ram (Sistem Belleği)', 'SSD Kapasitesi', 'İşlemci Çekirdek Sayısı', 'Price'
]

# Virgül haricindeki karakterleri temizleyelim
for col in sayisal_sutunlar:
    if col in df.columns:
        # Sayısal olmayan tüm karakterleri (virgül hariç) temizlemek için regex kullanacağız
        df[col] = df[col].replace(r'[^0-9.,]', '', regex=True)  # Virgül dışındaki her şeyi temizle
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Sayısal türüne dönüştür, hata olanları NaN yapar

# Veriyi yeni bir Excel dosyasına kaydedelim
df.to_excel('cleaned_data.xlsx', index=False)

print("Veri başarıyla 'cleaned_data.xlsx' dosyasına kaydedildi.")
# Out:
# Veri başarıyla 'cleaned_data.xlsx' dosyasına kaydedildi.

# %%
# Temizlenmiş Excel dosyasını yükleyelim
df = pd.read_excel('cleaned_data.xlsx')

# %%
df.dtypes
# Out:
# Arttırılabilir Azami Bellek     object
# Bağlantılar                     object
# Cihaz Ağırlığı                  object
# Dokunmatik Ekran                object
# Ekran Boyutu                    object
# Ekran Kartı                     object
# Ekran Kartı Bellek Tipi         object
# Ekran Kartı Gücü               float64
# Ekran Kartı Hafızası            object
# Ekran Kartı Tipi                object
# Ekran Yenileme Hızı            float64
# Garanti Süresi                  object
# Garanti Tipi                    object
# Hard Disk Kapasitesi           float64
# Kapasite                        object
# Klavye                          object
# Kullanım Amacı                  object
# Maksimum İşlemci Hızı (GHz)    float64
# Menşei                          object
# Panel Tipi                      object
# Price                          float64
# Ram (Sistem Belleği)             int64
# Ram (Sistem Belleği) Tipi       object
# Renk                            object
# SSD Kapasitesi                 float64
# Temel İşlemci Hızı (GHz)        object
# Title                           object
# Çözünürlük                      object
# Çözünürlük Standartı            object
# İşlemci Modeli                  object
# İşlemci Nesli                   object
# İşlemci Tipi                    object
# İşlemci Çekirdek Sayısı        float64
# İşletim Sistemi                 object
# Şarjlı Kullanım Süresi          object
# dtype: object

# %%
df.head()
# Out:
#   Arttırılabilir Azami Bellek             Bağlantılar Cihaz Ağırlığı  \
# 0                       16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 1                       16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 2                       16 GB  USB - Bluetooth - HDMI   2 kg ve altı
# 3                       32 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 4                       64 GB                    HDMI       2 - 4 kg
#
#   Dokunmatik Ekran Ekran Boyutu              Ekran Kartı  \
# 0              Yok     15,6 inç  Nvidia GeForce RTX 4060
# 1              Yok     15,6 inç  Nvidia GeForce RTX 3050
# 2              Yok     15,6 inç  Nvidia GeForce RTX 2050
# 3              Yok     15,6 inç  Nvidia GeForce RTX 4050
# 4              Yok     15,6 inç  Nvidia GeForce RTX 3050
#
#   Ekran Kartı Bellek Tipi  Ekran Kartı Gücü Ekran Kartı Hafızası  \
# 0                   GDDR6               NaN                 8 GB
# 1                   GDDR6               NaN                 6 GB
# 2                   GDDR6              55.0         4 GB ve altı
# 3                   GDDR6             105.0                 6 GB
# 4                   GDDR6               NaN         4 GB ve altı
#
#   Ekran Kartı Tipi  ...  Temel İşlemci Hızı (GHz)  \
# 0           Harici  ...                       NaN
# 1           Harici  ...                       NaN
# 2           Harici  ...                       2.3
# 3           Harici  ...                       3.1
# 4           Harici  ...                       2.5
#
#                                                Title   Çözünürlük  \
# 0  LOQ 15IAX9 83GS007XTR i5-12450HX 8GB 512 GB SS...  1920 x 1080
# 1  G15-5530 Intel Core i7-13650HX 16GB 512GB SSD ...  1920 x 1080
# 2  Abra A5 V21.3 Intel Core i7 12700H 16 GB RAM 5...  1920 x 1080
# 3  LOQ Intel Core i5-12450HX 16GB 512GB SSD 6GB R...  1920 x 1080
# 4  Excalibur G770.1245-BVJ0X-B i5-12450H 16GB RAM...  1920 x 1080
#
#    Çözünürlük Standartı İşlemci Modeli İşlemci Nesli   İşlemci Tipi  \
# 0         Full HD (FHD)  Belirtilmemiş     12. Nesil  Intel Core i5
# 1         Full HD (FHD)        13650HX     13. Nesil  Intel Core i7
# 2         Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 3         Full HD (FHD)         12450H     12. Nesil  Intel Core i5
# 4         Full HD (FHD)         12450H     12. Nesil  Intel Core i5
#
#    İşlemci Çekirdek Sayısı İşletim Sistemi Şarjlı Kullanım Süresi
# 0                      8.0        Free Dos                    NaN
# 1                     24.0        Free Dos                    NaN
# 2                     14.0        Free Dos               4-6 Saat
# 3                      8.0        Free Dos         6 Saat ve Üstü
# 4                      8.0        Free Dos                    NaN
#
# [5 rows x 35 columns]

# %%
df['Ekran Kartı'][:3]
# Out:
# 0    Nvidia GeForce RTX 4060
# 1    Nvidia GeForce RTX 3050
# 2    Nvidia GeForce RTX 2050
# Name: Ekran Kartı, dtype: object

# %% [markdown]
# Veri setimizin betimsel istatistiklerine ulaşmak için describe() fonksiyonunu kullanıyoruz.
#
# Bu fonksiyon eksik verileri göz ardı eder ve default olarak yalnızca numerik değişkenlere bakar.

# %%
df.describe().T # -> .T eklentisi elde edeceğimiz çıktıyı transpose eder.

# df.describe(include = "all") -> Veri setindeki tüm değişkenleri dahil etmek için include parametresine "all" değerini verebilirsiniz.
# Out:
#                               count         mean         std      min  \
# Ekran Kartı Gücü              260.0   106.673077   35.070101   45.000
# Ekran Yenileme Hızı          1156.0   160.863322   38.729838   60.000
# Hard Disk Kapasitesi           41.0   244.463415  252.476246    1.000
# Maksimum İşlemci Hızı (GHz)   742.0     4.739218    0.264521    4.200
# Price                         786.0    48.739373   28.523317   15.049
# Ram (Sistem Belleği)         1200.0    30.793333   22.997928    8.000
# SSD Kapasitesi               1195.0  1063.986611  940.029965  256.000
# İşlemci Çekirdek Sayısı      1199.0    12.558799    6.013869    1.000
#
#                                  25%       50%       75%       max
# Ekran Kartı Gücü              95.000   105.000   140.000   175.000
# Ekran Yenileme Hızı          144.000   144.000   165.000   360.000
# Hard Disk Kapasitesi           1.000     2.000   500.000   500.000
# Maksimum İşlemci Hızı (GHz)    4.500     4.700     5.000     5.000
# Price                         32.224    41.599    49.999   238.399
# Ram (Sistem Belleği)          16.000    24.000    32.000   128.000
# SSD Kapasitesi               512.000  1024.000  1024.000  8192.000
# İşlemci Çekirdek Sayısı        8.000    12.000    16.000    24.000

# %%
df["SSD Kapasitesi"].mode()[0]
# Out:
# np.float64(1024.0)

# %% [markdown]
# # 2- EKSİK VERİ ANALİZİ

# %% [markdown]
# Eksik Veri Analizi ile, veri setimizdeki eksik verileri tespit edip bu durumu uygun bir şekilde düzeltmeyi hedefleriz.
#
# Veri seti içerisinde eksik değerler bulunması yapısal bir bozukluğa işaret eder ve mutlaka uygun yöntemlerle ele alınmalıdır.
#
# Eksik veriler, duruma bağlı olarak veri setinden silinebilir veya uygun veriler ile doldurulabilir. Ancak eksik verilerin silinmesi, silinen satır veya sütunlar içerisinde yer alan diğer verilerin kaybedilmesi anlamına gelir. Eksik verilerin doldurulması işleminde ise, veri setine sentetik bir girdi yapacağımızdan dolayı, doldurma işlemleri veri setindeki dağılımları manipüle edebilir (veri setinde yanlılık oluşturabilir).
#
# Eksik verilerin ne sebeple ortaya çıktığı hassas bir şekilde değerlendirilmeli, nasıl ele alınacağı da bu değerlendirme sonucunda uygun şekilde karar verilmelidir.

# %% [markdown]
# 1. isna() metodu:
# Pandas'taki DataFrame veya Series içinde eksik (NaN) değerleri kontrol etmek için kullanılır.
# Eğer bir hücrede eksik veri (NaN) varsa, bu hücre için True döner, yoksa False döner.
# Boşu true dönderir.

# %% [markdown]
# 2. isnull() metodu:
# isna() metodu ile aynı işlevi görür. Yani, eksik (NaN) değerleri kontrol eder ve her bir hücre için True veya False döner.
# Pandas'ta isna() ve isnull() birbirinin yerine kullanılabilir. Aralarındaki fark sadece metod adıdır. Yani, biri diğerine eşdeğerdir.

# %%
def save_to_excel(df, file_name="cleaned_data.xlsx"):
    """
    Bu fonksiyon, verilen DataFrame'i belirtilen dosya adına kaydeder.

    Args:
    - df: Pandas DataFrame
    - file_name: Kaydedilecek Excel dosyasının adı
    """
    df.to_excel(file_name, index=False)
    print(f"Dosya '{file_name}' adıyla başarıyla kaydedildi.")

# %%
df.isna().sum() # -> isna() methodu yerine isnull() methodu da kullanılabilir.
# Out:
# Arttırılabilir Azami Bellek     390
# Bağlantılar                       3
# Cihaz Ağırlığı                    0
# Dokunmatik Ekran                  0
# Ekran Boyutu                      0
# Ekran Kartı                       0
# Ekran Kartı Bellek Tipi           0
# Ekran Kartı Gücü                940
# Ekran Kartı Hafızası              0
# Ekran Kartı Tipi                  0
# Ekran Yenileme Hızı              44
# Garanti Süresi                    0
# Garanti Tipi                      0
# Hard Disk Kapasitesi           1159
# Kapasite                       1199
# Klavye                            0
# Kullanım Amacı                    0
# Maksimum İşlemci Hızı (GHz)     458
# Menşei                         1190
# Panel Tipi                        1
# Price                           414
# Ram (Sistem Belleği)              0
# Ram (Sistem Belleği) Tipi         0
# Renk                              0
# SSD Kapasitesi                    5
# Temel İşlemci Hızı (GHz)        767
# Title                             0
# Çözünürlük                        0
# Çözünürlük Standartı              0
# İşlemci Modeli                    0
# İşlemci Nesli                     0
# İşlemci Tipi                      0
# İşlemci Çekirdek Sayısı           1
# İşletim Sistemi                   0
# Şarjlı Kullanım Süresi          885
# dtype: int64

# %%
# Eksik değerlerin sayısını ve oranını hesaplama
missing_data = df.isnull().sum()  # Eksik değerlerin sayısını alıyoruz
missing_percentage = (missing_data / len(df)) * 100  # Oranı hesaplıyoruz

# %%
missing_percentage
# Out:
# Arttırılabilir Azami Bellek    32.500000
# Bağlantılar                     0.250000
# Cihaz Ağırlığı                  0.000000
# Dokunmatik Ekran                0.000000
# Ekran Boyutu                    0.000000
# Ekran Kartı                     0.000000
# Ekran Kartı Bellek Tipi         0.000000
# Ekran Kartı Gücü               78.333333
# Ekran Kartı Hafızası            0.000000
# Ekran Kartı Tipi                0.000000
# Ekran Yenileme Hızı             3.666667
# Garanti Süresi                  0.000000
# Garanti Tipi                    0.000000
# Hard Disk Kapasitesi           96.583333
# Kapasite                       99.916667
# Klavye                          0.000000
# Kullanım Amacı                  0.000000
# Maksimum İşlemci Hızı (GHz)    38.166667
# Menşei                         99.166667
# Panel Tipi                      0.083333
# Price                          34.500000
# Ram (Sistem Belleği)            0.000000
# Ram (Sistem Belleği) Tipi       0.000000
# Renk                            0.000000
# SSD Kapasitesi                  0.416667
# Temel İşlemci Hızı (GHz)       63.916667
# Title                           0.000000
# Çözünürlük                      0.000000
# Çözünürlük Standartı            0.000000
# İşlemci Modeli                  0.000000
# İşlemci Nesli                   0.000000
# İşlemci Tipi                    0.000000
# İşlemci Çekirdek Sayısı         0.083333
# İşletim Sistemi                 0.000000
# Şarjlı Kullanım Süresi         73.750000
# dtype: float64

# %% [markdown]
# Veri setindeki toplam eksik değer sayısını görmek için tekrar sum() fonksiyonu ekleyebiliriz.

# %%
df.isna().sum().sum()
# Out:
# np.int64(7456)

# %%
# Her bir sütundaki ne kadar veri olduğunu gösterir.
df.notnull().sum()
# Out:
# Arttırılabilir Azami Bellek     810
# Bağlantılar                    1197
# Cihaz Ağırlığı                 1200
# Dokunmatik Ekran               1200
# Ekran Boyutu                   1200
# Ekran Kartı                    1200
# Ekran Kartı Bellek Tipi        1200
# Ekran Kartı Gücü                260
# Ekran Kartı Hafızası           1200
# Ekran Kartı Tipi               1200
# Ekran Yenileme Hızı            1156
# Garanti Süresi                 1200
# Garanti Tipi                   1200
# Hard Disk Kapasitesi             41
# Kapasite                          1
# Klavye                         1200
# Kullanım Amacı                 1200
# Maksimum İşlemci Hızı (GHz)     742
# Menşei                           10
# Panel Tipi                     1199
# Price                           786
# Ram (Sistem Belleği)           1200
# Ram (Sistem Belleği) Tipi      1200
# Renk                           1200
# SSD Kapasitesi                 1195
# Temel İşlemci Hızı (GHz)        433
# Title                          1200
# Çözünürlük                     1200
# Çözünürlük Standartı           1200
# İşlemci Modeli                 1200
# İşlemci Nesli                  1200
# İşlemci Tipi                   1200
# İşlemci Çekirdek Sayısı        1199
# İşletim Sistemi                1200
# Şarjlı Kullanım Süresi          315
# dtype: int64

# %% [markdown]
# None ve NaN değerler arasındaki fark nedir?
#
# None (null) değerler ile NaN değerler arasındaki farkın ne olduğunu görmek için güzel bir kaynak: https://medium.com/@allenhuang1996/whats-the-difference-between-null-and-nan-in-python-a1af20d523ce

# %%
# Veri setinde toplam kaç adet eksik gözlem var, kaç adet eksik olmayan gözlem var görelim.
print(f"Veri seti içerisinde toplam {df.notnull().sum().sum()} adet eksik olmayan, {df.isnull().sum().sum()} eksik gözlem var.")
# Out:
# Veri seti içerisinde toplam 34544 adet eksik olmayan, 7456 eksik gözlem var.

# %%
# Veri setinde en az bir gözlemi eksik olan kayıtlara da ulaşabiliriz.
df[df.isnull().any(axis = 1)]
# Out:
#      Arttırılabilir Azami Bellek             Bağlantılar Cihaz Ağırlığı  \
# 0                          16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 1                          16 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 2                          16 GB  USB - Bluetooth - HDMI   2 kg ve altı
# 3                          32 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 4                          64 GB                    HDMI       2 - 4 kg
# ...                          ...                     ...            ...
# 1195                       64 GB  USB - Bluetooth - HDMI       2 - 4 kg
# 1196                         NaN  USB - Bluetooth - HDMI       2 - 4 kg
# 1197                         NaN  USB - Bluetooth - HDMI       2 - 4 kg
# 1198                         NaN  USB - Bluetooth - HDMI       2 - 4 kg
# 1199                         NaN  USB - Bluetooth - HDMI       2 - 4 kg
#
#      Dokunmatik Ekran Ekran Boyutu                 Ekran Kartı  \
# 0                 Yok     15,6 inç     Nvidia GeForce RTX 4060
# 1                 Yok     15,6 inç     Nvidia GeForce RTX 3050
# 2                 Yok     15,6 inç     Nvidia GeForce RTX 2050
# 3                 Yok     15,6 inç     Nvidia GeForce RTX 4050
# 4                 Yok     15,6 inç     Nvidia GeForce RTX 3050
# ...               ...          ...                         ...
# 1195              Yok     17,3 inç     Nvidia GeForce RTX 4060
# 1196              Yok       16 inç  Nvidia GeForce RTX 3050 Ti
# 1197              Yok     15,6 inç     Nvidia GeForce RTX 4060
# 1198              Yok     15,6 inç     Nvidia GeForce RTX 4060
# 1199              Yok     15,6 inç     Nvidia GeForce RTX 4060
#
#      Ekran Kartı Bellek Tipi  Ekran Kartı Gücü Ekran Kartı Hafızası  \
# 0                      GDDR6               NaN                 8 GB
# 1                      GDDR6               NaN                 6 GB
# 2                      GDDR6              55.0         4 GB ve altı
# 3                      GDDR6             105.0                 6 GB
# 4                      GDDR6               NaN         4 GB ve altı
# ...                      ...               ...                  ...
# 1195                   GDDR6             105.0                 8 GB
# 1196                   GDDR6               NaN         4 GB ve altı
# 1197                   GDDR6               NaN                 8 GB
# 1198                   GDDR6               NaN                 8 GB
# 1199                   GDDR6               NaN                 8 GB
#
#      Ekran Kartı Tipi  ...  Temel İşlemci Hızı (GHz)  \
# 0              Harici  ...                       NaN
# 1              Harici  ...                       NaN
# 2              Harici  ...                       2.3
# 3              Harici  ...                       3.1
# 4              Harici  ...                       2.5
# ...               ...  ...                       ...
# 1195           Harici  ...                       1.8
# 1196           Harici  ...                       NaN
# 1197           Harici  ...                       NaN
# 1198           Harici  ...                       NaN
# 1199           Harici  ...                       NaN
#
#                                                   Title   Çözünürlük  \
# 0     LOQ 15IAX9 83GS007XTR i5-12450HX 8GB 512 GB SS...  1920 x 1080
# 1     G15-5530 Intel Core i7-13650HX 16GB 512GB SSD ...  1920 x 1080
# 2     Abra A5 V21.3 Intel Core i7 12700H 16 GB RAM 5...  1920 x 1080
# 3     LOQ Intel Core i5-12450HX 16GB 512GB SSD 6GB R...  1920 x 1080
# 4     Excalibur G770.1245-BVJ0X-B i5-12450H 16GB RAM...  1920 x 1080
# ...                                                 ...          ...
# 1195  Katana 17 B13VFK37 i7 13620H 96GB 256GB SSD RT...  1920 x 1080
# 1196  GU603ZE-LS012 INTEL / I7-12700 / 16GB / 512GB ...  1920 x 1200
# 1197  Nitro 5 i7 12700H 48GB 4TB SSD RTX4060/8GB 165...  1920 x 1080
# 1198  Nitro 5 i7 12700H 32GB 4TB SSD RTX4060/8GB 165...  1920 x 1080
# 1199  Nitro 5 i7 12700H 64GB 2TB SSD RTX4060/8GB 165...  1920 x 1080
#
#       Çözünürlük Standartı İşlemci Modeli İşlemci Nesli   İşlemci Tipi  \
# 0            Full HD (FHD)  Belirtilmemiş     12. Nesil  Intel Core i5
# 1            Full HD (FHD)        13650HX     13. Nesil  Intel Core i7
# 2            Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 3            Full HD (FHD)         12450H     12. Nesil  Intel Core i5
# 4            Full HD (FHD)         12450H     12. Nesil  Intel Core i5
# ...                    ...            ...           ...            ...
# 1195         Full HD (FHD)         13620H     13. Nesil  Intel Core i7
# 1196         Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 1197         Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 1198         Full HD (FHD)         12700H     12. Nesil  Intel Core i7
# 1199         Full HD (FHD)         12700H     12. Nesil  Intel Core i7
#
#       İşlemci Çekirdek Sayısı İşletim Sistemi Şarjlı Kullanım Süresi
# 0                         8.0        Free Dos                    NaN
# 1                        24.0        Free Dos                    NaN
# 2                        14.0        Free Dos               4-6 Saat
# 3                         8.0        Free Dos         6 Saat ve Üstü
# 4                         8.0        Free Dos                    NaN
# ...                       ...             ...                    ...
# 1195                     16.0         Windows                    NaN
# 1196                     14.0        Free Dos                    NaN
# 1197                     14.0         Windows                    NaN
# 1198                     14.0         Windows                    NaN
# 1199                     14.0         Windows                    NaN
#
# [1200 rows x 35 columns]

# %%
# Hiç eksik gözlemi bulunmayan kayıtları getirelim.
df[df.notnull().all(axis = 1)][:5]
# Out:
# Empty DataFrame
# Columns: [Arttırılabilir Azami Bellek, Bağlantılar, Cihaz Ağırlığı, Dokunmatik Ekran, Ekran Boyutu, Ekran Kartı, Ekran Kartı Bellek Tipi, Ekran Kartı Gücü, Ekran Kartı Hafızası, Ekran Kartı Tipi, Ekran Yenileme Hızı, Garanti Süresi, Garanti Tipi, Hard Disk Kapasitesi, Kapasite, Klavye, Kullanım Amacı, Maksimum İşlemci Hızı (GHz), Menşei, Panel Tipi, Price, Ram (Sistem Belleği), Ram (Sistem Belleği) Tipi, Renk, SSD Kapasitesi, Temel İşlemci Hızı (GHz), Title, Çözünürlük, Çözünürlük Standartı, İşlemci Modeli, İşlemci Nesli, İşlemci Tipi, İşlemci Çekirdek Sayısı, İşletim Sistemi, Şarjlı Kullanım Süresi]
# Index: []
#
# [0 rows x 35 columns]

# %%
#!pip install missingno -> missingno kütüphanesini kullanabilmek için öncelikle yüklemeniz lazım.
import missingno as msno

msno.bar(df = df,
         figsize = (15, 5),
         fontsize = 12);

# %%
# Yukarıda görülen grafiğe bakarak kapasite ve menşei'nin bizim yapacağımız modele bir faydası olmadığından ve verileri eksik olduğundan siliyoruz.
df.drop(columns="Arttırılabilir Azami Bellek",axis=1,inplace=True)
df.drop(columns="Bağlantılar",axis=1,inplace=True)
df.drop(columns="Cihaz Ağırlığı",axis=1,inplace=True)
df.drop(columns="Dokunmatik Ekran",axis=1,inplace=True)
df.drop(columns="Garanti Süresi",axis=1,inplace=True)
df.drop(columns="Garanti Tipi",axis=1,inplace=True)
df.drop(columns="Kapasite", axis=1, inplace=True)
df.drop(columns="Klavye",axis=1,inplace=True)
df.drop(columns="Kullanım Amacı",axis=1,inplace=True)
df.drop(columns="Menşei", axis=1, inplace=True)
df.drop(columns="Temel İşlemci Hızı (GHz)", axis=1, inplace=True)
df.drop(columns="Title", axis=1, inplace=True)
df.drop(columns="Çözünürlük", axis=1, inplace=True)
df.drop(columns="Çözünürlük Standartı", axis=1, inplace=True)
df.drop(columns="Şarjlı Kullanım Süresi", axis=1, inplace=True)

# 'Price' sütununu en sona taşımak
columns = [col for col in df.columns if col != 'Price']  # 'Price' dışındaki sütunları al
columns.append('Price')  # 'Price' sütununu sona ekle

# Yeni sütun sırasına göre DataFrame'i yeniden düzenle
df = df[columns]

save_to_excel(df)
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.

# %%
print(list(df.columns))
# Out:
# ['Ekran Boyutu', 'Ekran Kartı', 'Ekran Kartı Bellek Tipi', 'Ekran Kartı Gücü', 'Ekran Kartı Hafızası', 'Ekran Kartı Tipi', 'Ekran Yenileme Hızı', 'Hard Disk Kapasitesi', 'Maksimum İşlemci Hızı (GHz)', 'Panel Tipi', 'Ram (Sistem Belleği)', 'Ram (Sistem Belleği) Tipi', 'Renk', 'SSD Kapasitesi', 'İşlemci Modeli', 'İşlemci Nesli', 'İşlemci Tipi', 'İşlemci Çekirdek Sayısı', 'İşletim Sistemi', 'Price']

# %%
len(df.columns)
# Out:
# 20

# %%
'Kapasite' in df.columns
# Out:
# False

# %%
df.dtypes
# Out:
# Ekran Boyutu                    object
# Ekran Kartı                     object
# Ekran Kartı Bellek Tipi         object
# Ekran Kartı Gücü               float64
# Ekran Kartı Hafızası            object
# Ekran Kartı Tipi                object
# Ekran Yenileme Hızı            float64
# Hard Disk Kapasitesi           float64
# Maksimum İşlemci Hızı (GHz)    float64
# Panel Tipi                      object
# Ram (Sistem Belleği)             int64
# Ram (Sistem Belleği) Tipi       object
# Renk                            object
# SSD Kapasitesi                 float64
# İşlemci Modeli                  object
# İşlemci Nesli                   object
# İşlemci Tipi                    object
# İşlemci Çekirdek Sayısı        float64
# İşletim Sistemi                 object
# Price                          float64
# dtype: object

# %%
import missingno as msno

msno.bar(df = df,
         figsize = (15, 5),
         fontsize = 12);

# %%
# Nullity Correlation (Heatmap)
# 1'e ne kadar yakınsa, ilişki ihtimali o kadar yüksek.
# 0 ise, birbirlerini etkileyen bir durum yoktur.
msno.heatmap(df = df,
             figsize = (10, 6),
             fontsize = 10);

# %% [markdown]
# # 2.1 - Eksik Verilerin Silinmesi

# %% [markdown]
# Veri setinde bulunan eksik verilere müdahale yöntemlerinden birisi, eksik verilerin silinmesidir. Uygulaması oldukça kolay bir yöntem olsa da eksik verileri silmeden önce dikkat edilmesi gereken önemli hususlar vardır.
#
# Eksik bir verinin bulunduğu gözlemi silmeya karar verebilmek için, bu eksikliğin doğal olmayan bir şekilde ortaya çıktığından emin olmamız gerekir. Örneğin elimizdeki bir araç veri setinde elektrikli araçlar için motor hacmi kolonunda Na değer bulunması doğal bir eksikliğe işaret eder. Bu durumda silme işlemi yerine uygun bir şekilde doldurmak tercih edilebilir.
#
# Eksik veriler veri setinde kayda değer bir yüzdeyi oluşturuyorsa, eksik verilerin silinmesi durumunda veri setindeki birçok gözlemi kaybedeceğimiz unutulmamalıdır. Bu durumda veri seti içerisinde bize bilgi sağlayabilecek birçok veriyi de kaybetmiş olacağız. Verinin olabildiğince fazla olması, hem analitik yöntemler hem de makine öğrenmesi yöntemleri için oldukça önemli olduğuna göre, veri setinden olabildiğince az kayıp verecek yöntemler denemeliyiz.

# %%
# Eksik verilerin dropna ile silinmesi.
# Kalıcı bir değişiklik yapmaz, bunu yapmak için inplace argümanı kullanılmalı veya atama yapılmalıdır.

df.dropna(inplace = False)[:10]
#df = df.dropna()
# Out:
# Empty DataFrame
# Columns: [Ekran Boyutu, Ekran Kartı, Ekran Kartı Bellek Tipi, Ekran Kartı Gücü, Ekran Kartı Hafızası, Ekran Kartı Tipi, Ekran Yenileme Hızı, Hard Disk Kapasitesi, Maksimum İşlemci Hızı (GHz), Panel Tipi, Ram (Sistem Belleği), Ram (Sistem Belleği) Tipi, Renk, SSD Kapasitesi, İşlemci Modeli, İşlemci Nesli, İşlemci Tipi, İşlemci Çekirdek Sayısı, İşletim Sistemi, Price]
# Index: []

# %%
# Sadece bütün değerleri eksik olan bir gözlemi silmek istersek;
df.dropna(how = 'all')[:5]
# Out:
#   Ekran Boyutu              Ekran Kartı Ekran Kartı Bellek Tipi  \
# 0     15,6 inç  Nvidia GeForce RTX 4060                   GDDR6
# 1     15,6 inç  Nvidia GeForce RTX 3050                   GDDR6
# 2     15,6 inç  Nvidia GeForce RTX 2050                   GDDR6
# 3     15,6 inç  Nvidia GeForce RTX 4050                   GDDR6
# 4     15,6 inç  Nvidia GeForce RTX 3050                   GDDR6
#
#    Ekran Kartı Gücü Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 0               NaN                 8 GB           Harici
# 1               NaN                 6 GB           Harici
# 2              55.0         4 GB ve altı           Harici
# 3             105.0                 6 GB           Harici
# 4               NaN         4 GB ve altı           Harici
#
#    Ekran Yenileme Hızı  Hard Disk Kapasitesi  Maksimum İşlemci Hızı (GHz)  \
# 0                  NaN                   NaN                          NaN
# 1                120.0                   NaN                          NaN
# 2                144.0                   NaN                          4.7
# 3                144.0                   NaN                          4.4
# 4                144.0                   NaN                          4.4
#
#   Panel Tipi  Ram (Sistem Belleği) Ram (Sistem Belleği) Tipi      Renk  \
# 0        IPS                     8                      DDR5    Renkli
# 1         VA                    16                      DDR5     Siyah
# 2        IPS                    16                      DDR4     Siyah
# 3    Full HD                    16                      DDR5  Luna Gri
# 4        IPS                    16                      DDR4     Siyah
#
#    SSD Kapasitesi İşlemci Modeli İşlemci Nesli   İşlemci Tipi  \
# 0           512.0  Belirtilmemiş     12. Nesil  Intel Core i5
# 1           512.0        13650HX     13. Nesil  Intel Core i7
# 2           500.0         12700H     12. Nesil  Intel Core i7
# 3           512.0         12450H     12. Nesil  Intel Core i5
# 4           500.0         12450H     12. Nesil  Intel Core i5
#
#    İşlemci Çekirdek Sayısı İşletim Sistemi   Price
# 0                      8.0        Free Dos  34.999
# 1                     24.0        Free Dos  34.899
# 2                     14.0        Free Dos  28.089
# 3                      8.0        Free Dos  34.999
# 4                      8.0        Free Dos  26.499

# %% [markdown]
# # 2.2 - Eksik Verilerin Doldurulması

# %% [markdown]
# Eksik verilerin doldurulması kararı, silinmesi işleminde olduğu gibi hassas ve bilinçli bir şekilde değerlendirilmesi gereken bir karardır. Zira doldurma işlemi veride gürültü (noise) oluşturabilir ve verinin istatistiksel olarak güvenilirliğini zedeleyebilir. Analitik durumlar içinse yanlış bilgi çıkarımlarına sebebiyet verebilir. Bu nedenle en sağlıklı doldurma kararının alındığı durumlarda dahi bu yanlılık durumu mutlaka göz önünde bulundurulmalıdır.

# %%
# Doldurma işlemlerini gerçekleştirmek için veri setimin bir kopyasını oluşturuyorum.
df_fillna = df.copy()

df_fillna.head(3)
# Out:
#   Ekran Boyutu              Ekran Kartı Ekran Kartı Bellek Tipi  \
# 0     15,6 inç  Nvidia GeForce RTX 4060                   GDDR6
# 1     15,6 inç  Nvidia GeForce RTX 3050                   GDDR6
# 2     15,6 inç  Nvidia GeForce RTX 2050                   GDDR6
#
#    Ekran Kartı Gücü Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 0               NaN                 8 GB           Harici
# 1               NaN                 6 GB           Harici
# 2              55.0         4 GB ve altı           Harici
#
#    Ekran Yenileme Hızı  Hard Disk Kapasitesi  Maksimum İşlemci Hızı (GHz)  \
# 0                  NaN                   NaN                          NaN
# 1                120.0                   NaN                          NaN
# 2                144.0                   NaN                          4.7
#
#   Panel Tipi  Ram (Sistem Belleği) Ram (Sistem Belleği) Tipi    Renk  \
# 0        IPS                     8                      DDR5  Renkli
# 1         VA                    16                      DDR5   Siyah
# 2        IPS                    16                      DDR4   Siyah
#
#    SSD Kapasitesi İşlemci Modeli İşlemci Nesli   İşlemci Tipi  \
# 0           512.0  Belirtilmemiş     12. Nesil  Intel Core i5
# 1           512.0        13650HX     13. Nesil  Intel Core i7
# 2           500.0         12700H     12. Nesil  Intel Core i7
#
#    İşlemci Çekirdek Sayısı İşletim Sistemi   Price
# 0                      8.0        Free Dos  34.999
# 1                     24.0        Free Dos  34.899
# 2                     14.0        Free Dos  28.089

# %%
df_fillna.isna().sum()
# Out:
# Ekran Boyutu                      0
# Ekran Kartı                       0
# Ekran Kartı Bellek Tipi           0
# Ekran Kartı Gücü                940
# Ekran Kartı Hafızası              0
# Ekran Kartı Tipi                  0
# Ekran Yenileme Hızı              44
# Hard Disk Kapasitesi           1159
# Maksimum İşlemci Hızı (GHz)     458
# Panel Tipi                        1
# Ram (Sistem Belleği)              0
# Ram (Sistem Belleği) Tipi         0
# Renk                              0
# SSD Kapasitesi                    5
# İşlemci Modeli                    0
# İşlemci Nesli                     0
# İşlemci Tipi                      0
# İşlemci Çekirdek Sayısı           1
# İşletim Sistemi                   0
# Price                           414
# dtype: int64

# %%
print(len(df_fillna.columns))
# Out:
# 20

# %% [markdown]
# ## 2.2.1 - "Ekran Boyutu" Sütununda Yapılan İşlemler
#
# Aşağıdaki işlemler, "Ekran Boyutu" sütunundaki verilerin temizlenmesi ve metin (string) formatına dönüştürülmesi için yapılmıştır:
#
# 1. **Boşlukların Temizlenmesi**: `str.strip()` fonksiyonu kullanılarak, "Ekran Boyutu" sütunundaki baştaki ve sondaki boşluklar temizlenmiştir. Bu işlem, verinin daha düzgün bir şekilde işlenebilmesi için önemlidir.
#
# 2. **'İnç' İfadesinin Kaldırılması**: `str.replace()` fonksiyonu ile "Ekran Boyutu" sütunundaki her değerin sonunda yer alan 'inç' ifadesi kaldırılmıştır. Bu, sayısal bir analiz yapabilmek için gereklidir.
#
# 3. **Metin Olarak Saklanması**: `astype(str)` fonksiyonu kullanılarak, "Ekran Boyutu" sütunundaki tüm veriler metin (string) formatına dönüştürülmüştür. Bu sayede, sayısal olmayan değerler ve kalan veriler metin olarak saklanır.
#
# 4. **Verilerin Kaydedilmesi**: İşlem tamamlandığında, veri seti `save_to_excel()` fonksiyonu ile Excel dosyasına kaydedilmiştir (eğer isteniyorsa).
#
# Sonuç olarak, "Ekran Boyutu" sütunundaki boşluklar temizlenmiş, 'inç' ifadesi kaldırılmış ve kalan veriler metin (string) olarak saklanmıştır.

# %%
# Ekran Boyutu sütunundaki baştaki ve sondaki boşlukları temizleyelim
df_fillna['Ekran Boyutu'] = df_fillna['Ekran Boyutu'].str.strip()

# Ekran Boyutu sütunundaki 'inç' ifadesini sonundan kaldıralım
df_fillna['Ekran Boyutu'] = df_fillna['Ekran Boyutu'].str.replace(r'inç$', '', regex=True)

# Kalan ifadeleri metin (string) olarak saklayalım
df_fillna['Ekran Boyutu'] = df_fillna['Ekran Boyutu'].astype(str)

# Sonrasında dosyayı kaydedelim
save_to_excel(df_fillna)

# İşlemin başarıyla tamamlandığını bildirelim
print("Ekran Boyutu sütunundaki 'inç' ifadeleri kaldırıldı ve metin olarak saklandı.")
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# Ekran Boyutu sütunundaki 'inç' ifadeleri kaldırıldı ve metin olarak saklandı.

# %% [markdown]
# ## 2.2.2 - "Maksimum İşlemci Hızı (GHz)" Sütununda Yapılan İşlemler
#
# Aşağıdaki işlemler, "Maksimum İşlemci Hızı (GHz)" sütunundaki eksik (NaN) değerleri doldurmak için yapılmıştır:
#
# 1. **Ortalama (Mean) Değerinin Hesaplanması**: `mean()` fonksiyonu ile "Maksimum İşlemci Hızı (GHz)" sütununun ortalama değeri hesaplanmıştır. Bu değer, eksik hücrelerde kullanılmak üzere belirlenmiştir.
#
# 2. **Eksik Değerlerin Ortalama Değerle Doldurulması**: `fillna()` fonksiyonu ile sütundaki eksik (NaN) değerler, hesaplanan ortalama değerle doldurulmuştur. Bu işlem `inplace=True` parametresi ile doğrudan DataFrame üzerinde yapılmıştır, yani yeni bir değişken oluşturulmamıştır.
#
# Sonuç olarak, "Maksimum İşlemci Hızı (GHz)" sütunundaki eksik değerler ortalama değerle doldurulmuş ve veri seti eksiksiz hale getirilmiştir.

# %%
# Maksimum İşlemci Hızı (GHz) sütununun ortalama (mean) değerini hesaplayalım
mean_islemci = df_fillna['Maksimum İşlemci Hızı (GHz)'].mean()

# Virgülden sonra yalnızca 1 basamağa yuvarlayalım
mean_islemci = round(mean_islemci, 1)

print(mean_islemci)

# Maksimum İşlemci Hızı (GHz) sütunundaki eksik değerleri ortalama değer ile dolduralım
df_fillna['Maksimum İşlemci Hızı (GHz)'].fillna(value=mean_islemci, inplace=True)

# Maksimum İşlemci Hızı (GHz)'nın 742 tane kaydı vardı. kaydı olanların ortalamasını alarak boş olan satırlara ekledik.
# Out:
# 4.7
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\3848615271.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Maksimum İşlemci Hızı (GHz)'].fillna(value=mean_islemci, inplace=True)

# %%
df_fillna['Maksimum İşlemci Hızı (GHz)']
# Out:
# 0       4.7
# 1       4.7
# 2       4.7
# 3       4.4
# 4       4.4
#        ...
# 1195    4.9
# 1196    4.7
# 1197    4.7
# 1198    4.7
# 1199    4.7
# Name: Maksimum İşlemci Hızı (GHz), Length: 1200, dtype: float64

# %%
import missingno as msno

msno.bar(df = df_fillna,
         figsize = (15, 5),
         fontsize = 12);

# %%
df_fillna.describe().T
# Out:
#                               count         mean         std      min  \
# Ekran Kartı Gücü              260.0   106.673077   35.070101   45.000
# Ekran Yenileme Hızı          1156.0   160.863322   38.729838   60.000
# Hard Disk Kapasitesi           41.0   244.463415  252.476246    1.000
# Maksimum İşlemci Hızı (GHz)  1200.0     4.724250    0.208822    4.200
# Ram (Sistem Belleği)         1200.0    30.793333   22.997928    8.000
# SSD Kapasitesi               1195.0  1063.986611  940.029965  256.000
# İşlemci Çekirdek Sayısı      1199.0    12.558799    6.013869    1.000
# Price                         786.0    48.739373   28.523317   15.049
#
#                                  25%       50%       75%       max
# Ekran Kartı Gücü              95.000   105.000   140.000   175.000
# Ekran Yenileme Hızı          144.000   144.000   165.000   360.000
# Hard Disk Kapasitesi           1.000     2.000   500.000   500.000
# Maksimum İşlemci Hızı (GHz)    4.700     4.700     4.900     5.000
# Ram (Sistem Belleği)          16.000    24.000    32.000   128.000
# SSD Kapasitesi               512.000  1024.000  1024.000  8192.000
# İşlemci Çekirdek Sayısı        8.000    12.000    16.000    24.000
# Price                         32.224    41.599    49.999   238.399

# %% [markdown]
# ## 2.2.3 - "Ekran Kartı Hafızası" Sütununda Yapılan İşlemler
#
# Aşağıdaki işlemler, "Ekran Kartı Hafızası" sütunundaki verileri temizlemek ve uygun hale getirmek için yapılmıştır:
#
# 1. **Baş ve Son Boşluklar Temizlendi**: `str.strip()` ile sütundaki tüm değerlerin başındaki ve sonundaki boşluklar kaldırıldı.
#
# 2. **"ve altı" İfadesi Silindi**: `str.replace(' ve altı', '')` ile tüm değerlerden `"ve altı"` ifadesi kaldırıldı.
#
# 3. **"Paylaşımlı" İfadesi Silindi**: `replace('Paylaşımlı', '')` ile `"Paylaşımlı"` ifadesi boş string ile değiştirildi.
#
# 4. **"GB" İfadesi Sonundan Kaldırıldı**: `str.replace(r'GB$', '')` ile tüm değerlerin sonundaki `"GB"` ifadesi silindi.
#
# 5. **Sayısal Değere Dönüştürüldü**: `pd.to_numeric()` ile sütun sayısal verilere dönüştürüldü ve geçersiz değerler `NaN` olarak işaretlendi.
#
# Sonuç olarak, bu işlemler sayesinde sütun sadece sayısal değerleri içerecek şekilde temizlendi ve analiz için hazır hale getirildi.

# %%
# 'Ekran Kartı Hafızası' sütunundaki baştaki ve sondaki boşlukları temizleyip 've altı' ifadesini silme
df_fillna['Ekran Kartı Hafızası'] = df_fillna['Ekran Kartı Hafızası'].str.strip().str.replace(' ve altı', '', regex=False)
# Yorum: str.strip() baştaki ve sondaki boşlukları temizler.
# str.replace(' ve altı', '') 've altı' ifadesini siler.

# 'Ekran Kartı Hafızası' sütununda 'Paylaşımlı' ifadesini boş string ile değiştirme
df_fillna["Ekran Kartı Hafızası"] = df_fillna["Ekran Kartı Hafızası"].replace('Paylaşımlı', '')
# Yorum: 'Paylaşımlı' ifadesini boşlukla değiştirir. Bu, ekran kartı hafızasında paylaşımlı yazan hücrelerde boşluk bırakır.

# 'Ekran Kartı Hafızası' sütunundaki 'GB' ifadesini silme
df_fillna['Ekran Kartı Hafızası'] = df_fillna['Ekran Kartı Hafızası'].str.replace(r'GB$', '', regex=True)
# Yorum: 'GB' ifadesinin metnin sonunda olması durumunda (GB$ regex ile) siler. Bu, GB'nin yalnızca son kısmını kaldırır.

# 'Ekran Kartı Hafızası' sütununu sayısal (numeric) değere dönüştürme
df_fillna['Ekran Kartı Hafızası'] = pd.to_numeric(df_fillna['Ekran Kartı Hafızası'], errors='coerce')
# Yorum: 'Ekran Kartı Hafızası' sütunundaki değerleri sayısal (numeric) veri türüne dönüştürür. 
# Eğer dönüşüm mümkün değilse, o hücreyi 'NaN' yapar (errors='coerce').

# Sonrasında dosyayı tekrar kaydedin
save_to_excel(df_fillna)
# Yorum: Verilen DataFrame'i (df_fillna) yeni haliyle Excel dosyasına kaydeder. (save_to_excel fonksiyonu dışarıdan tanımlanmış olmalı).
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.

# %%
df_fillna["Ekran Kartı Hafızası"].head()
# Out:
# 0    8.0
# 1    6.0
# 2    4.0
# 3    6.0
# 4    4.0
# Name: Ekran Kartı Hafızası, dtype: float64

# %%
# 'Ekran Kartı Hafızası' sütunundaki farklı değerleri görmek için
print(df_fillna['Ekran Kartı Hafızası'].unique())
# Out:
# [ 8.  6.  4. nan 16. 12.]

# %%
# 'Ekran Kartı Hafızası' sütunundaki NaN değerlerinin sayısını görmek
nan_count_column = df_fillna['Ekran Kartı Hafızası'].isna().sum()
print(f"'Ekran Kartı Hafızası' sütunundaki NaN sayısı: {nan_count_column}")
# Out:
# 'Ekran Kartı Hafızası' sütunundaki NaN sayısı: 49

# %%
# 'Ekran Kartı Hafızası' sütunundaki en çok tekrar eden değeri bulma
most_frequent_value = df_fillna['Ekran Kartı Hafızası'].mode()[0]

# 'Ekran Kartı Hafızası' sütunundaki boş değerleri ("" veya " ") NaN ile değiştirme
df_fillna['Ekran Kartı Hafızası'] = df_fillna['Ekran Kartı Hafızası'].replace(['', ' '], pd.NA)

# NaN hücrelerini en çok tekrar eden değerle doldurma
df_fillna['Ekran Kartı Hafızası'] = df_fillna['Ekran Kartı Hafızası'].fillna(most_frequent_value)

# Kaydetme fonksiyonu
save_to_excel(df_fillna)

# Sonuçları kontrol etme
print(f"En çok tekrar eden değer: {most_frequent_value}")
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# En çok tekrar eden değer: 8.0

# %%
df_fillna["Ekran Kartı Hafızası"].unique()
# Out:
# array([ 8.,  6.,  4., 16., 12.])

# %% [markdown]
# ## 2.2.4 - "Ekran Kartı Gücü" Sütununda Yapılan İşlemler
#
# Aşağıdaki işlemler, "Ekran Kartı Gücü" sütunundaki eksik (NaN) değerleri doldurmak için yapılmıştır:
#
# 1. **En Sık (Mode) Değeri Hesaplama**: `mean()` fonksiyonu yerine `mode()` kullanarak "Ekran Kartı Gücü" sütunundaki en sık tekrar eden değeri bulmak daha doğru olacaktır. Ancak burada `mean()` yerine `mode()` kullanmamışız ve yanlış bir işlem yapılmış. Bunu düzeltmek için, `mode()` fonksiyonu kullanılmalı.
#
# 2. **Eksik (NaN) Değerleri Mode ile Doldurma**: `fillna()` fonksiyonu ile sütundaki eksik (NaN) değerler, en sık tekrar eden değerle doldurulmuştur.
#
# 3. **Eksik Değerlerin Durumunu Kontrol Etme**: `isna().sum()` fonksiyonu kullanılarak sütundaki eksik (NaN) değerlerin sayısı kontrol edilmiştir.
#
# 4. **Veriyi Kaydetme**: Temizlenen veriler, `save_to_excel()` fonksiyonu ile Excel dosyasına kaydedilmiştir.
#
# Bu işlemler sonucunda, "Ekran Kartı Gücü" sütunundaki eksik veriler en sık tekrar eden değerle doldurulmuş ve veri seti kaydedilmiştir.

# %%
df_fillna[['Ekran Kartı Gücü']][100:300]
# Out:
#      Ekran Kartı Gücü
# 100               NaN
# 101               NaN
# 102               NaN
# 103               NaN
# 104               NaN
# ..                ...
# 295             120.0
# 296             105.0
# 297               NaN
# 298               NaN
# 299              95.0
#
# [200 rows x 1 columns]

# %%
# Ekran Kartı Gücü sütununun en sık (mode) değerini bulalım
ekran_karti_mode = int(df_fillna['Ekran Kartı Gücü'].mean())

# Ekran Kartı Gücü sütunundaki eksik değerleri mode ile dolduralım
df_fillna['Ekran Kartı Gücü'] = df_fillna['Ekran Kartı Gücü'].fillna(value=ekran_karti_mode)

# Veriyi Excel dosyasına kaydedelim
save_to_excel(df_fillna)

print("Veriler Excel'e kaydedildi.")
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# Veriler Excel'e kaydedildi.

# %%
df_fillna[['Ekran Kartı Gücü']][:20]
# Out:
#     Ekran Kartı Gücü
# 0              106.0
# 1              106.0
# 2               55.0
# 3              105.0
# 4              106.0
# 5              106.0
# 6              106.0
# 7              106.0
# 8              106.0
# 9              106.0
# 10             106.0
# 11             106.0
# 12             106.0
# 13             106.0
# 14             106.0
# 15             106.0
# 16             106.0
# 17             106.0
# 18             106.0
# 19             106.0

# %%
# Eksik değerlerin son durumunu kontrol edelim
print("Eksik değerler (NaN) sayısı:", df_fillna.isna().sum())
# Out:
# Eksik değerler (NaN) sayısı: Ekran Boyutu                      0
# Ekran Kartı                       0
# Ekran Kartı Bellek Tipi           0
# Ekran Kartı Gücü                  0
# Ekran Kartı Hafızası              0
# Ekran Kartı Tipi                  0
# Ekran Yenileme Hızı              44
# Hard Disk Kapasitesi           1159
# Maksimum İşlemci Hızı (GHz)       0
# Panel Tipi                        1
# Ram (Sistem Belleği)              0
# Ram (Sistem Belleği) Tipi         0
# Renk                              0
# SSD Kapasitesi                    5
# İşlemci Modeli                    0
# İşlemci Nesli                     0
# İşlemci Tipi                      0
# İşlemci Çekirdek Sayısı           1
# İşletim Sistemi                   0
# Price                           414
# dtype: int64

# %%
import missingno as msno

msno.bar(df = df_fillna,
         figsize = (15, 5),
         fontsize = 12);

# %% [markdown]
# ## 2.2.5 - "Ekran Yenileme Hızı" Sütununda Yapılan İşlemler
#
# Aşağıdaki işlemler, "Ekran Yenileme Hızı" sütunundaki eksik (NaN) değerleri doldurmak için yapılmıştır:
#
# 1. **Ekran Yenileme Hızının Ortalama (Mean) Değerinin Hesaplanması**: `mode()` fonksiyonu kullanılarak "Ekran Yenileme Hızı" sütununun en çok tekrar eden değeri hesaplanmıştır. Bu tekrar eden değer, eksik (NaN) değerleri doldurmak için kullanılacaktır.
#
# 2. **Eksik Değerlerin En Çok Tekrar Eden Değerle Doldurulması**: `fillna()` fonksiyonu ile, sütundaki eksik (NaN) değerler hesaplanan ortalama değer ile doldurulmuştur. Bu işlem `inplace=True` parametresi ile doğrudan DataFrame üzerinde gerçekleştirilmiştir, yani yeni bir değişken oluşturulmamıştır.
#
# Sonuç olarak, "Ekran Yenileme Hızı" sütunundaki eksik değerler ortalama değeriyle doldurulmuş ve veri seti eksiksiz hale getirilmiştir.

# %%
# "Ekran Yenileme Hızı" sütununun ortalama (mean) değerini hesaplayalım
mode_ekran_yenileme = df_fillna['Ekran Yenileme Hızı'].mode()
print(mode_ekran_yenileme)

# Ekran Yenileme Hızı sütunundaki eksik değerleri ortalama değer ile dolduralım
df_fillna['Ekran Yenileme Hızı'].fillna(value=mode_ekran_yenileme, inplace=True)

save_to_excel(df = df_fillna)
# Out:
# 0    144.0
# Name: Ekran Yenileme Hızı, dtype: float64
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\2440962837.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Ekran Yenileme Hızı'].fillna(value=mode_ekran_yenileme, inplace=True)
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.

# %%
# Sonuçları kontrol etmek için
print("Eksik değerler (NaN) sayısı:", df_fillna.isna().sum())
# Out:
# Eksik değerler (NaN) sayısı: Ekran Boyutu                      0
# Ekran Kartı                       0
# Ekran Kartı Bellek Tipi           0
# Ekran Kartı Gücü                  0
# Ekran Kartı Hafızası              0
# Ekran Kartı Tipi                  0
# Ekran Yenileme Hızı              43
# Hard Disk Kapasitesi           1159
# Maksimum İşlemci Hızı (GHz)       0
# Panel Tipi                        1
# Ram (Sistem Belleği)              0
# Ram (Sistem Belleği) Tipi         0
# Renk                              0
# SSD Kapasitesi                    5
# İşlemci Modeli                    0
# İşlemci Nesli                     0
# İşlemci Tipi                      0
# İşlemci Çekirdek Sayısı           1
# İşletim Sistemi                   0
# Price                           414
# dtype: int64

# %% [markdown]
# # Hard Disk Kapasitesi sil
# Çok az veri olduğu için silinmiştir.

# %%
df_fillna.drop(columns="Hard Disk Kapasitesi", axis=1, inplace=True)
save_to_excel(df= df_fillna)
# Out:
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.

# %%
list(df_fillna.columns)
# Out:
# ['Ekran Boyutu',
#  'Ekran Kartı',
#  'Ekran Kartı Bellek Tipi',
#  'Ekran Kartı Gücü',
#  'Ekran Kartı Hafızası',
#  'Ekran Kartı Tipi',
#  'Ekran Yenileme Hızı',
#  'Maksimum İşlemci Hızı (GHz)',
#  'Panel Tipi',
#  'Ram (Sistem Belleği)',
#  'Ram (Sistem Belleği) Tipi',
#  'Renk',
#  'SSD Kapasitesi',
#  'İşlemci Modeli',
#  'İşlemci Nesli',
#  'İşlemci Tipi',
#  'İşlemci Çekirdek Sayısı',
#  'İşletim Sistemi',
#  'Price']

# %% [markdown]
# # İşlemci Modeli Belirtilmemişse boş bırak

# %%
# 'Belirtilmemiş' değerlerini boş string ("") ile değiştirme
df_fillna["İşlemci Modeli"] = df_fillna["İşlemci Modeli"].replace("Belirtilmemiş", "")

# Boş stringleri NaN ile değiştirelim ki fillna() kullanabilelim
df_fillna['İşlemci Modeli'].replace("", pd.NA, inplace=True)

# 'İşlemci Modeli' sütunundaki en sık tekrar eden değeri (mode) bulma
mode_islemci_değeri = df_fillna['İşlemci Modeli'].mode()[0]

# Mode değerini yazdıralım
print(f"En sık tekrar eden değer: {mode_islemci_değeri}")

# Eksik (NaN) değerleri en sık tekrarlanan değerle doldurma
df_fillna['İşlemci Modeli'].fillna(value=mode_islemci_değeri, inplace=True)

# Dosyayı kaydedelim
save_to_excel(df=df_fillna)

# İşlemin tamamlandığını belirten mesaj
print("İşlemci Modeli sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.")
# Out:
# En sık tekrar eden değer: 12450H
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\2990617831.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['İşlemci Modeli'].replace("", pd.NA, inplace=True)
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\2990617831.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['İşlemci Modeli'].fillna(value=mode_islemci_değeri, inplace=True)
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# İşlemci Modeli sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.

# %%
df_fillna["İşlemci Modeli"].head()
# Out:
# 0     12450H
# 1    13650HX
# 2     12700H
# 3     12450H
# 4     12450H
# Name: İşlemci Modeli, dtype: object

# %% [markdown]
# RAM Bilgilerini Güncelleme

# %%
# 'Belirtilmemiş' değerlerini boş string ("") ile değiştirme
df_fillna["Ram (Sistem Belleği) Tipi"] = df_fillna["Ram (Sistem Belleği) Tipi"].replace("Belirtilmemiş", "")

# Boş stringleri NaN ile değiştirelim ki fillna() kullanabilelim
df_fillna['Ram (Sistem Belleği) Tipi'].replace("", pd.NA, inplace=True)

# 'İşlemci Modeli' sütunundaki en sık tekrar eden değeri (mode) bulma
mode_islemci_değeri = df_fillna['Ram (Sistem Belleği) Tipi'].mode()[0]

# Mode değerini yazdıralım
print(f"En sık tekrar eden değer: {mode_islemci_değeri}")

# Eksik (NaN) değerleri en sık tekrarlanan değerle doldurma
df_fillna['Ram (Sistem Belleği) Tipi'].fillna(value=mode_islemci_değeri, inplace=True)

# Dosyayı kaydedelim
save_to_excel(df=df_fillna)

# İşlemin tamamlandığını belirten mesaj
print("Ram (Sistem Belleği) Tipi sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.")
# Out:
# En sık tekrar eden değer: DDR5
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\1981999915.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Ram (Sistem Belleği) Tipi'].replace("", pd.NA, inplace=True)
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\1981999915.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Ram (Sistem Belleği) Tipi'].fillna(value=mode_islemci_değeri, inplace=True)
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# Ram (Sistem Belleği) Tipi sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.

# %% [markdown]
# Price Bilgilerini Güncelleme

# %%
# 'Belirtilmemiş' değerlerini boş string ("") ile değiştirme
df_fillna["Price"] = df_fillna["Price"].replace("Belirtilmemiş", "")

# Boş stringleri NaN ile değiştirelim ki fillna() kullanabilelim
df_fillna['Price'].replace("", pd.NA, inplace=True)

# 'İşlemci Modeli' sütunundaki en sık tekrar eden değeri (mode) bulma
mean_fiyat = df_fillna['Price'].mean()

# Mode değerini yazdıralım
print(f"Ortalama Değer: {mean_fiyat}")

# Eksik (NaN) değerleri en sık tekrarlanan değerle doldurma
df_fillna['Price'].fillna(value=mean_fiyat, inplace=True)

# Dosyayı kaydedelim
save_to_excel(df=df_fillna)

# İşlemin tamamlandığını belirten mesaj
print("Price sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.")
# Out:
# Ortalama Değer: 48.7393727735369
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\3533175497.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Price'].replace("", pd.NA, inplace=True)
# C:\Users\Muhammed Emre\AppData\Local\Temp\ipykernel_15628\3533175497.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fillna['Price'].fillna(value=mean_fiyat, inplace=True)
# Dosya 'cleaned_data.xlsx' adıyla başarıyla kaydedildi.
# Price sütunundaki eksik veriler dolduruldu ve dosya kaydedildi.

# %%
import missingno as msno

msno.bar(df = df_fillna,
         figsize = (15, 5),
         fontsize = 12);

# %%
df = df_fillna.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ekran Boyutu                 1200 non-null   object
#  1   Ekran Kartı                  1200 non-null   object
#  2   Ekran Kartı Bellek Tipi      1200 non-null   object
#  3   Ekran Kartı Gücü             1200 non-null   float64
#  4   Ekran Kartı Hafızası         1200 non-null   float64
#  5   Ekran Kartı Tipi             1200 non-null   object
#  6   Ekran Yenileme Hızı          1157 non-null   float64
#  7   Maksimum İşlemci Hızı (GHz)  1200 non-null   float64
#  8   Panel Tipi                   1199 non-null   object
#  9   Ram (Sistem Belleği)         1200 non-null   int64
#  10  Ram (Sistem Belleği) Tipi    1200 non-null   object
#  11  Renk                         1200 non-null   object
#  12  SSD Kapasitesi               1195 non-null   float64
#  13  İşlemci Modeli               1200 non-null   object
#  14  İşlemci Nesli                1200 non-null   object
#  15  İşlemci Tipi                 1200 non-null   object
#  16  İşlemci Çekirdek Sayısı      1199 non-null   float64
#  17  İşletim Sistemi              1200 non-null   object
#  18  Price                        1200 non-null   float64
# dtypes: float64(7), int64(1), object(11)
# memory usage: 178.3+ KB

# %%
# Spesifik bir veri tipi tutan değişkenleri seçmek için select_dtypes() kullanabiliriz.
df_categorical = df.select_dtypes(include = "object")
df_categorical.head(3)
# Out:
#   Ekran Boyutu              Ekran Kartı Ekran Kartı Bellek Tipi  \
# 0        15,6   Nvidia GeForce RTX 4060                   GDDR6
# 1        15,6   Nvidia GeForce RTX 3050                   GDDR6
# 2        15,6   Nvidia GeForce RTX 2050                   GDDR6
#
#   Ekran Kartı Tipi Panel Tipi Ram (Sistem Belleği) Tipi    Renk  \
# 0           Harici        IPS                      DDR5  Renkli
# 1           Harici         VA                      DDR5   Siyah
# 2           Harici        IPS                      DDR4   Siyah
#
#   İşlemci Modeli İşlemci Nesli   İşlemci Tipi İşletim Sistemi
# 0         12450H     12. Nesil  Intel Core i5        Free Dos
# 1        13650HX     13. Nesil  Intel Core i7        Free Dos
# 2         12700H     12. Nesil  Intel Core i7        Free Dos

# %%
# Kategorik değişkenlerdeki benzersiz değerlerin sayısını görebilmek için nunique() kullanabiliriz.
for col in df_categorical.columns:
    print(f'There are {df_categorical[col].nunique()} unique values in "{col}" categorical feature.\n')
# Out:
# There are 11 unique values in "Ekran Boyutu" categorical feature.
#
# There are 25 unique values in "Ekran Kartı" categorical feature.
#
# There are 6 unique values in "Ekran Kartı Bellek Tipi" categorical feature.
#
# There are 2 unique values in "Ekran Kartı Tipi" categorical feature.
#
# There are 10 unique values in "Panel Tipi" categorical feature.
#
# There are 5 unique values in "Ram (Sistem Belleği) Tipi" categorical feature.
#
# There are 49 unique values in "Renk" categorical feature.
#
# There are 61 unique values in "İşlemci Modeli" categorical feature.
#
# There are 11 unique values in "İşlemci Nesli" categorical feature.
#
# There are 10 unique values in "İşlemci Tipi" categorical feature.
#
# There are 3 unique values in "İşletim Sistemi" categorical feature.

# %%
# Her bir kategorik değişken için toplam gözlem sayısını value_counts() ile buluyoruz.
for col in df_categorical.columns:
    print(f'{df_categorical[col].value_counts()}\n', 5*"*********")
# Out:
# Ekran Boyutu
# 15,6             726
# 17,3             202
# 16               138
# 16,1              79
# 18                21
# 17                15
# 14                13
# 7,0                3
# 13,3               1
# 15,4               1
# Belirtilmemiş      1
# Name: count, dtype: int64
#  *********************************************
# Ekran Kartı
# Nvidia GeForce RTX 4050       293
# Nvidia GeForce RTX 4060       258
# Nvidia GeForce RTX 3050       173
# Nvidia GeForce RTX 4070       135
# Nvidia GeForce RTX 2050       121
# Nvidia GeForce RTX 4080       113
# Nvidia GeForce RTX 4090        28
# Dahili Ekran Kartı             17
# Nvidia GeForce RTX 3050 Ti     13
# Nvidia GeForce RTX3060         13
# AMD Radeon RX7600S              8
# Nvidia GeForce MX550            6
# Nvidia GeForce RTX 3070         4
# Nvidia GeForce RTX 3070Ti       4
# AMD Radeon Graphics             3
# Nvidia GeForce GTX 1650         2
# AMD Radeon RX 6550M             1
# Nvidia Quadro T2000             1
# Nvidia GeForce RTX 3080         1
# Nvidia GeForce GTX 1050         1
# Nvidia GeForce RTX 2060         1
# RTX 2070 SUPER Max-q            1
# AMD Radeon RX6500M              1
# Nvidia GeForce GTX1650 Ti       1
# Nvidia GeForce MX330            1
# Name: count, dtype: int64
#  *********************************************
# Ekran Kartı Bellek Tipi
# GDDR6            1077
# Belirtilmemiş      40
# DDR5               37
# DDR4               26
# GDDR6X             16
# GDDR5               4
# Name: count, dtype: int64
#  *********************************************
# Ekran Kartı Tipi
# Harici    1129
# Dahili      71
# Name: count, dtype: int64
#  *********************************************
# Panel Tipi
# IPS              1064
# TN                 48
# Full HD            31
# OLED               14
# VA                 11
# Anti-Glare          8
# LED                 7
# Yok                 7
# WUXGA               6
# Mikro Kenarlı       3
# Name: count, dtype: int64
#  *********************************************
# Ram (Sistem Belleği) Tipi
# DDR5       719
# DDR4       460
# LPDDR5X     14
# LPDDR5       6
# DDR6         1
# Name: count, dtype: int64
#  *********************************************
# Renk
# Siyah                 654
# Gri                   145
# Koyu Mavi              90
# Koyu Gri               69
# Renkli                 30
# SİYAH                  28
# siyah                  23
# Mavi                   17
# Beyaz                  12
# GRİ                    11
# Blue                   11
# KOYU GRİ-SİYAH          9
# Çok Renkli              9
# Luna Gri                7
# Gümüş                   6
# Mika Gümüşü             6
# gri                     5
# Koyu mavi               5
# Mika Gümüş              5
# Off Black               4
# Eclipse Gray            4
# Mecha Gray              4
# GRAFİT SİYAH            4
# Ay Grisi                3
# Black                   3
# KOYU GRİ                3
# SIYAH                   2
# MİKA GÜMÜŞ              2
# Siyah/Kırmızı           2
# Uzay Gri                2
# Metalik Uzay Grisi      2
# Lacivert                2
# Onyx Grey               2
# Gölge Siyahı            2
# Jaeger Gray             2
# MAVİ                    2
# MİKA GÜMÜŞÜ             1
# Cloud Gri               1
# Graphite Black          1
# Metalik                 1
# Grafiti Siyah           1
# Inox                    1
# Oniks Grisi             1
# Belirtilmemiş           1
# mavi                    1
# METALİKGRİ              1
# Storm Grey              1
# Tutulma Siyahı          1
# White                   1
# Name: count, dtype: int64
#  *********************************************
# İşlemci Modeli
# 12450H     206
# 13900HX    116
# 13500H     111
# 12700H      86
# 13620H      81
#           ...
# 6800HS       1
# 10300H       1
# 6660U        1
# 1135G7       1
# 1255U        1
# Name: count, Length: 61, dtype: int64
#  *********************************************
# İşlemci Nesli
# 13. Nesil        492
# 12. Nesil        295
# 7. Nesil          96
# 14. Nesil         90
# 8. Nesil          75
# Belirtilmemiş     70
# 5. Nesil          42
# 11. Nesil         21
# 6. Nesil           9
# 10. Nesil          5
# 1. Nesil           5
# Name: count, dtype: int64
#  *********************************************
# İşlemci Tipi
# Intel Core i7         375
# Intel Core i5         364
# Intel Core i9         178
# AMD Ryzen 5           132
# AMD Ryzen 7            95
# AMD Ryzen 9            34
# Intel Core Ultra 9      7
# Intel Core Ultra 7      7
# AMD Ryzen AI 9          6
# Ryzen Z1                2
# Name: count, dtype: int64
#  *********************************************
# İşletim Sistemi
# Free Dos    653
# Windows     509
# Linux        38
# Name: count, dtype: int64
#  *********************************************

# %%
# Kategorik bir değişkende bulunan kategorik değerleri bir liste haline getirip sonra kullanabiliriz.
comp_categories = df["İşlemci Modeli"].unique().tolist()[::-1]
comp_categories
# Out:
# ['1255U',
#  '1135G7',
#  '6660U',
#  '10300H',
#  'HX 370',
#  '1235U',
#  '11600H',
#  '6800HS',
#  '12450HX',
#  '10750H',
#  '11800H',
#  '8645HS',
#  '7845HX',
#  '6600H',
#  'i5-11320H',
#  '1355U',
#  '13500HX',
#  '155H',
#  '13900H',
#  '13950HX',
#  '185H',
#  '5800H',
#  '8640H',
#  '11980HK',
#  '6800H',
#  '7840HS',
#  '14650HX',
#  '8840H',
#  '12900H',
#  '14500HX',
#  '11320H',
#  '11370H',
#  '8850H',
#  '10870H',
#  '13700HX',
#  '13500H',
#  '8845HS',
#  '7500U',
#  '7940HS',
#  '7735HS',
#  '5600H',
#  '7640HS',
#  '13980HX',
#  '11400H',
#  '8945HS',
#  '14700HX',
#  '14900HX',
#  '13900HX',
#  '7435HS',
#  '13700H',
#  '550',
#  '12650H',
#  '5700U',
#  '7535HS',
#  '5500H',
#  '12500H',
#  '13620H',
#  '13420H',
#  '12700H',
#  '13650HX',
#  '12450H']

# %%
# Kategorik bir değişkendeki kategorilerin gözlem sayılarını basitçe görselleştirelim.
df['Panel Tipi'].value_counts().plot.barh();

# %%
sns.countplot(data = df,
              y = "Panel Tipi",
              hue = "Panel Tipi",
              order = df["Panel Tipi"].value_counts().index,
              palette = "Set1");

# %%
# Barplot için doğru kullanım
#sns.barplot(data=df, x="Panel Tipi", y="Panel Tipi")
import seaborn as sns
import matplotlib.pyplot as plt

# Reset index ve barplot çizimi
sns.barplot(data=df.reset_index(), x="Panel Tipi", y="index")

# x ve y etiketlerini döndürmek için:
plt.xticks(rotation=90)  # x ekseni etiketlerini 90 derece döndür
plt.yticks(rotation=90)  # y ekseni etiketlerini 90 derece döndür (gerekiyorsa)

# Grafiği gösterme
plt.show()

# %%
sns.catplot(data = df,
            x = "Panel Tipi",
            y = "Price");

# %% [markdown]
# Bu kod parçası, bir veri kümesi (df) üzerinde bir sütun grafiği (barplot) oluşturur. Grafik, işlemci tipine göre fiyatları ve işletim sistemine göre fiyat dağılımını görselleştirir.

# %%
plt.figure(figsize = (15, 8))
sns.barplot(data = df,
            x = "İşlemci Tipi",
            y = "Price",
            hue = "İşletim Sistemi");

# %%
df.columns
# Out:
# Index(['Ekran Boyutu', 'Ekran Kartı', 'Ekran Kartı Bellek Tipi',
#        'Ekran Kartı Gücü', 'Ekran Kartı Hafızası', 'Ekran Kartı Tipi',
#        'Ekran Yenileme Hızı', 'Maksimum İşlemci Hızı (GHz)', 'Panel Tipi',
#        'Ram (Sistem Belleği)', 'Ram (Sistem Belleği) Tipi', 'Renk',
#        'SSD Kapasitesi', 'İşlemci Modeli', 'İşlemci Nesli', 'İşlemci Tipi',
#        'İşlemci Çekirdek Sayısı', 'İşletim Sistemi', 'Price'],
#       dtype='object')

# %%
#Kod, "İşlemci Modeli" sütununa göre gruplandırma yaparak, her işlemci modeline ait fiyatların ortalamasını alır ve sonuçları sıralar.
df_price = df.groupby(by = "İşlemci Modeli")["Price"].mean().to_frame().reset_index().sort_values(by = "İşlemci Modeli", ascending = False)

df_price
# Out:
#    İşlemci Modeli      Price
# 60      i5-11320H  32.498000
# 59         HX 370  67.199000
# 58         8945HS  52.580197
# 57          8850H  51.282333
# 56         8845HS  49.669320
# ..            ...        ...
# 4          1135G7  48.739373
# 3          11320H  29.699333
# 2          10870H  48.739373
# 1          10750H  63.399000
# 0          10300H  35.957000
#
# [61 rows x 2 columns]

# %%
df_price = df.groupby(by = "Ekran Kartı")["Price"].mean().to_frame().reset_index().sort_values(by = "Ekran Kartı", ascending = False)

df_price
# Out:
#                    Ekran Kartı       Price
# 24        RTX 2070 SUPER Max-q   63.399000
# 23         Nvidia Quadro T2000   87.999000
# 22      Nvidia GeForce RTX3060   59.532278
# 21     Nvidia GeForce RTX 4090  132.933272
# 20     Nvidia GeForce RTX 4080   53.814936
# 19     Nvidia GeForce RTX 4070   68.570564
# 18     Nvidia GeForce RTX 4060   50.840901
# 17     Nvidia GeForce RTX 4050   43.533627
# 16     Nvidia GeForce RTX 3080   79.999000
# 15   Nvidia GeForce RTX 3070Ti   51.304280
# 14     Nvidia GeForce RTX 3070   63.059093
# 13  Nvidia GeForce RTX 3050 Ti   39.322471
# 12     Nvidia GeForce RTX 3050   37.585116
# 11     Nvidia GeForce RTX 2060   25.799000
# 10     Nvidia GeForce RTX 2050   29.719425
# 9         Nvidia GeForce MX550   28.680729
# 8         Nvidia GeForce MX330   48.739373
# 7    Nvidia GeForce GTX1650 Ti   35.957000
# 6      Nvidia GeForce GTX 1650   35.639500
# 5      Nvidia GeForce GTX 1050   36.599000
# 4           Dahili Ekran Kartı   37.878022
# 3           AMD Radeon RX7600S   40.286250
# 2           AMD Radeon RX6500M   28.789000
# 1          AMD Radeon RX 6550M   22.999000
# 0          AMD Radeon Graphics   24.665667

# %%
df_price = (
    df.groupby(by=["Ekran Kartı", "Ram (Sistem Belleği)"])["Price"]
    .mean()
    .to_frame()
    .reset_index()
    .sort_values(by=["Ekran Kartı", "Ram (Sistem Belleği)"], ascending=[False, False])
)
df_price
# Out:
#                Ekran Kartı  Ram (Sistem Belleği)      Price
# 82    RTX 2070 SUPER Max-q                    32  63.399000
# 81     Nvidia Quadro T2000                    32  87.999000
# 80  Nvidia GeForce RTX3060                    64  48.739373
# 79  Nvidia GeForce RTX3060                    32  51.304280
# 78  Nvidia GeForce RTX3060                    16  64.995390
# ..                     ...                   ...        ...
# 4       AMD Radeon RX7600S                    16  36.886500
# 3       AMD Radeon RX6500M                    16  28.789000
# 2      AMD Radeon RX 6550M                    16  22.999000
# 1      AMD Radeon Graphics                    16  29.474000
# 0      AMD Radeon Graphics                     8  15.049000
#
# [83 rows x 3 columns]

# %% [markdown]
# Tablo, her İşlemci Tipi ve Ekran Kartı kombinasyonunun sayısını gösteriyor.

# %%
# İşlemci Tipi ve Ekran Kartı kombinasyonlarının sayısını bulma
df_combination_count = df.groupby(['İşlemci Tipi', 'Ekran Kartı']).size().reset_index(name='Kombinasyon Sayısı')

# Kombinasyonları sıralama
df_combination_count_sorted = df_combination_count.sort_values(by="Kombinasyon Sayısı", ascending=False)

df_combination_count_sorted
# Out:
#           İşlemci Tipi                 Ekran Kartı  Kombinasyon Sayısı
# 48       Intel Core i7     Nvidia GeForce RTX 4060                 166
# 39       Intel Core i5     Nvidia GeForce RTX 4050                 163
# 37       Intel Core i5     Nvidia GeForce RTX 3050                 110
# 57       Intel Core i9     Nvidia GeForce RTX 4080                 110
# 3          AMD Ryzen 5     Nvidia GeForce RTX 2050                  88
# 47       Intel Core i7     Nvidia GeForce RTX 4050                  79
# 49       Intel Core i7     Nvidia GeForce RTX 4070                  52
# 40       Intel Core i5     Nvidia GeForce RTX 4060                  50
# 16         AMD Ryzen 7     Nvidia GeForce RTX 4050                  39
# 43       Intel Core i7     Nvidia GeForce RTX 3050                  37
# 56       Intel Core i9     Nvidia GeForce RTX 4070                  34
# 22         AMD Ryzen 9     Nvidia GeForce RTX 4070                  31
# 58       Intel Core i9     Nvidia GeForce RTX 4090                  25
# 4          AMD Ryzen 5     Nvidia GeForce RTX 3050                  25
# 35       Intel Core i5     Nvidia GeForce RTX 2050                  24
# 17         AMD Ryzen 7     Nvidia GeForce RTX 4060                  22
# 18         AMD Ryzen 7     Nvidia GeForce RTX 4070                  13
# 51       Intel Core i7      Nvidia GeForce RTX3060                  11
# 6          AMD Ryzen 5     Nvidia GeForce RTX 4050                  11
# 41       Intel Core i7          Dahili Ekran Kartı                  10
# 42       Intel Core i7     Nvidia GeForce RTX 2050                   9
# 9          AMD Ryzen 7          AMD Radeon RX7600S                   8
# 55       Intel Core i9     Nvidia GeForce RTX 4060                   7
# 34       Intel Core i5        Nvidia GeForce MX550                   6
# 13         AMD Ryzen 7  Nvidia GeForce RTX 3050 Ti                   5
# 23      AMD Ryzen AI 9     Nvidia GeForce RTX 4060                   5
# 38       Intel Core i5  Nvidia GeForce RTX 3050 Ti                   5
# 7          AMD Ryzen 5     Nvidia GeForce RTX 4060                   4
# 29  Intel Core Ultra 9     Nvidia GeForce RTX 4070                   4
# 25  Intel Core Ultra 7          Dahili Ekran Kartı                   3
# 50       Intel Core i7     Nvidia GeForce RTX 4080                   3
# 45       Intel Core i7     Nvidia GeForce RTX 3070                   3
# 31       Intel Core i5          Dahili Ekran Kartı                   3
# 30  Intel Core Ultra 9     Nvidia GeForce RTX 4090                   3
# 44       Intel Core i7  Nvidia GeForce RTX 3050 Ti                   2
# 46       Intel Core i7   Nvidia GeForce RTX 3070Ti                   2
# 59            Ryzen Z1         AMD Radeon Graphics                   2
# 19         AMD Ryzen 7      Nvidia GeForce RTX3060                   2
# 21         AMD Ryzen 9     Nvidia GeForce RTX 4060                   2
# 27  Intel Core Ultra 7     Nvidia GeForce RTX 4060                   2
# 8          AMD Ryzen 7         AMD Radeon Graphics                   1
# 2          AMD Ryzen 5     Nvidia GeForce GTX 1650                   1
# 0          AMD Ryzen 5         AMD Radeon RX 6550M                   1
# 1          AMD Ryzen 5          AMD Radeon RX6500M                   1
# 26  Intel Core Ultra 7     Nvidia GeForce RTX 4050                   1
# 24      AMD Ryzen AI 9     Nvidia GeForce RTX 4070                   1
# 20         AMD Ryzen 9          Dahili Ekran Kartı                   1
# 14         AMD Ryzen 7     Nvidia GeForce RTX 3070                   1
# 12         AMD Ryzen 7     Nvidia GeForce RTX 3050                   1
# 15         AMD Ryzen 7   Nvidia GeForce RTX 3070Ti                   1
# 10         AMD Ryzen 7     Nvidia GeForce GTX 1050                   1
# 11         AMD Ryzen 7     Nvidia GeForce GTX 1650                   1
# 5          AMD Ryzen 5  Nvidia GeForce RTX 3050 Ti                   1
# 28  Intel Core Ultra 7         Nvidia Quadro T2000                   1
# 33       Intel Core i5        Nvidia GeForce MX330                   1
# 32       Intel Core i5   Nvidia GeForce GTX1650 Ti                   1
# 36       Intel Core i5     Nvidia GeForce RTX 2060                   1
# 54       Intel Core i9     Nvidia GeForce RTX 3080                   1
# 52       Intel Core i7        RTX 2070 SUPER Max-q                   1
# 53       Intel Core i9   Nvidia GeForce RTX 3070Ti                   1

# %%
# Veri setindeki numerik kolonları seçmek için aşağıdaki yapıyı kullanabiliriz.
df_numerical = df.select_dtypes(include = ["float64", "int64"])
df_numerical.head()
# Out:
#    Ekran Kartı Gücü  Ekran Kartı Hafızası  Ekran Yenileme Hızı  \
# 0             106.0                   8.0                144.0
# 1             106.0                   6.0                120.0
# 2              55.0                   4.0                144.0
# 3             105.0                   6.0                144.0
# 4             106.0                   4.0                144.0
#
#    Maksimum İşlemci Hızı (GHz)  Ram (Sistem Belleği)  SSD Kapasitesi  \
# 0                          4.7                     8           512.0
# 1                          4.7                    16           512.0
# 2                          4.7                    16           500.0
# 3                          4.4                    16           512.0
# 4                          4.4                    16           500.0
#
#    İşlemci Çekirdek Sayısı   Price
# 0                      8.0  34.999
# 1                     24.0  34.899
# 2                     14.0  28.089
# 3                      8.0  34.999
# 4                      8.0  26.499

# %%
df_numerical.describe().T
# Out:
#                               count         mean         std      min  \
# Ekran Kartı Gücü             1200.0   106.145833   16.301974   45.000
# Ekran Kartı Hafızası         1200.0     7.150000    2.633745    4.000
# Ekran Yenileme Hızı          1157.0   160.848747   38.716257   60.000
# Maksimum İşlemci Hızı (GHz)  1200.0     4.724250    0.208822    4.200
# Ram (Sistem Belleği)         1200.0    30.793333   22.997928    8.000
# SSD Kapasitesi               1195.0  1063.986611  940.029965  256.000
# İşlemci Çekirdek Sayısı      1199.0    12.558799    6.013869    1.000
# Price                        1200.0    48.739373   23.079440   15.049
#
#                                    25%          50%          75%       max
# Ekran Kartı Gücü             106.00000   106.000000   106.000000   175.000
# Ekran Kartı Hafızası           6.00000     6.000000     8.000000    16.000
# Ekran Yenileme Hızı          144.00000   144.000000   165.000000   360.000
# Maksimum İşlemci Hızı (GHz)    4.70000     4.700000     4.900000     5.000
# Ram (Sistem Belleği)          16.00000    24.000000    32.000000   128.000
# SSD Kapasitesi               512.00000  1024.000000  1024.000000  8192.000
# İşlemci Çekirdek Sayısı        8.00000    12.000000    16.000000    24.000
# Price                         38.07025    48.739373    48.739373   238.399

# %%
# Bir veri setindeki numerik kolonların istatistiksel bilgilerine erişmek için basitçe bu tarz bir fonksiyon yazabiliriz.

def give_stats(dataframe: pd.DataFrame) -> None:
    """Prints statistical information for numerical columns.

    Args:
        dataframe (pd.DataFrame): DataFrame object.
    
    Return:
        None
    
    """

    num_df = dataframe.select_dtypes(include = ["float", "int"])

    for col in num_df.columns:
        print(f"**********{col}**********")
        print(f"Mean value of {col} is {num_df[col].mean():.2f}")
        print(f"Std value of {col} is {num_df[col].std():.2f}")
        print(f"Max value of {col} is {num_df[col].max()}")
        print(f"Min value of {col} is {num_df[col].min()}")
        print(f"Count value of {col} is {num_df[col].count()}")
        print(f"Median value of {col} is {num_df[col].median()}\n")

# %%
give_stats(dataframe = df)
# Out:
# **********Ekran Kartı Gücü**********
# Mean value of Ekran Kartı Gücü is 106.15
# Std value of Ekran Kartı Gücü is 16.30
# Max value of Ekran Kartı Gücü is 175.0
# Min value of Ekran Kartı Gücü is 45.0
# Count value of Ekran Kartı Gücü is 1200
# Median value of Ekran Kartı Gücü is 106.0
#
# **********Ekran Kartı Hafızası**********
# Mean value of Ekran Kartı Hafızası is 7.15
# Std value of Ekran Kartı Hafızası is 2.63
# Max value of Ekran Kartı Hafızası is 16.0
# Min value of Ekran Kartı Hafızası is 4.0
# Count value of Ekran Kartı Hafızası is 1200
# Median value of Ekran Kartı Hafızası is 6.0
#
# **********Ekran Yenileme Hızı**********
# Mean value of Ekran Yenileme Hızı is 160.85
# Std value of Ekran Yenileme Hızı is 38.72
# Max value of Ekran Yenileme Hızı is 360.0
# Min value of Ekran Yenileme Hızı is 60.0
# Count value of Ekran Yenileme Hızı is 1157
# Median value of Ekran Yenileme Hızı is 144.0
#
# **********Maksimum İşlemci Hızı (GHz)**********
# Mean value of Maksimum İşlemci Hızı (GHz) is 4.72
# Std value of Maksimum İşlemci Hızı (GHz) is 0.21
# Max value of Maksimum İşlemci Hızı (GHz) is 5.0
# Min value of Maksimum İşlemci Hızı (GHz) is 4.2
# Count value of Maksimum İşlemci Hızı (GHz) is 1200
# Median value of Maksimum İşlemci Hızı (GHz) is 4.7
#
# **********Ram (Sistem Belleği)**********
# Mean value of Ram (Sistem Belleği) is 30.79
# Std value of Ram (Sistem Belleği) is 23.00
# Max value of Ram (Sistem Belleği) is 128
# Min value of Ram (Sistem Belleği) is 8
# Count value of Ram (Sistem Belleği) is 1200
# Median value of Ram (Sistem Belleği) is 24.0
#
# **********SSD Kapasitesi**********
# Mean value of SSD Kapasitesi is 1063.99
# Std value of SSD Kapasitesi is 940.03
# Max value of SSD Kapasitesi is 8192.0
# Min value of SSD Kapasitesi is 256.0
# Count value of SSD Kapasitesi is 1195
# Median value of SSD Kapasitesi is 1024.0
#
# **********İşlemci Çekirdek Sayısı**********
# Mean value of İşlemci Çekirdek Sayısı is 12.56
# Std value of İşlemci Çekirdek Sayısı is 6.01
# Max value of İşlemci Çekirdek Sayısı is 24.0
# Min value of İşlemci Çekirdek Sayısı is 1.0
# Count value of İşlemci Çekirdek Sayısı is 1199
# Median value of İşlemci Çekirdek Sayısı is 12.0
#
# **********Price**********
# Mean value of Price is 48.74
# Std value of Price is 23.08
# Max value of Price is 238.399
# Min value of Price is 15.049
# Count value of Price is 1200
# Median value of Price is 48.7393727735369

# %%
# Numerik bir kolonun dağılımını görmek için histogram kullanırız.
sns.histplot(data = df, x = "Ram (Sistem Belleği)", kde = True, hue = "Ekran Kartı Gücü");

# %% [markdown]
# Bu komut, RAM (Sistem Belleği) verisinin olasılık yoğunluğunu görsel olarak gösteren bir yoğunluk eğrisi çizer. KDE, histogramdan farklı olarak verinin dağılımını daha düzgün bir şekilde gösterir, böylece hangi değerlerin daha yoğun olduğunu, hangi aralıkların daha az yoğun olduğunu rahatlıkla gözlemleyebilirsiniz.

# %%
sns.kdeplot(df['Ram (Sistem Belleği)'], fill = True);

# %%
sns.FacetGrid(data = df,
              hue = "İşlemci Tipi",  # Kategorik bir sütun kullan
              height = 7,
              xlim = (0, 150
              )).map(sns.kdeplot, "Ram (Sistem Belleği)", fill = True).add_legend()
# Out:
# c:\conda\envs\data_science\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# Bu kod, en sık görülen 10 ekran kartını seçer ve her bir ekran kartı için Ram (Sistem Belleği) değerlerinin dağılımını boxplot ile gösterir. Yani her bir ekran kartı için sistem belleği değerlerinin nasıl dağıldığını, hangi ekran kartlarında yüksek veya düşük belleğe sahip makinelerin olduğunu gözlemleyebilirsiniz.

# %%
# İlk 10 ekran kartını seçmek için en sık görülen 10 ekran kartını al
top_10_ekran_karti = df['Ekran Kartı'].value_counts().nlargest(10).index

# Sadece ilk 10 ekran kartına ait veriyi filtreleme
df_top_10_ekran_karti = df[df['Ekran Kartı'].isin(top_10_ekran_karti)]

# Boxplot görsellemesi ile kategorik ve numerik dağılımı gösterme
sns.boxplot(data = df_top_10_ekran_karti,
            x = "Ekran Kartı",      # Kategorik değişken
            y = "Ram (Sistem Belleği)"            # Numerik değişken
            ) # Kategorik değişken (gözlem gruplaması için)

# Ekran Kartı etiketlerini yatay (yan) olarak yazdırma
plt.xticks(rotation=90)  # x eksenindeki etiketleri 90 derece döndürerek yan yazdırma

# Grafiği göster
plt.show()

# %%
df.columns
# Out:
# Index(['Ekran Boyutu', 'Ekran Kartı', 'Ekran Kartı Bellek Tipi',
#        'Ekran Kartı Gücü', 'Ekran Kartı Hafızası', 'Ekran Kartı Tipi',
#        'Ekran Yenileme Hızı', 'Maksimum İşlemci Hızı (GHz)', 'Panel Tipi',
#        'Ram (Sistem Belleği)', 'Ram (Sistem Belleği) Tipi', 'Renk',
#        'SSD Kapasitesi', 'İşlemci Modeli', 'İşlemci Nesli', 'İşlemci Tipi',
#        'İşlemci Çekirdek Sayısı', 'İşletim Sistemi', 'Price'],
#       dtype='object')
